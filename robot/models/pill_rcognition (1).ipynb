# %%
# !pip install ultralytics opencv-python pillow matplotlib --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.9 MB/s eta 0:00:00

# %%
import torch

print("GPU available: " ,torch.cuda.is_available())
print("Device name: ", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "no gpu detected")
# Out:
# GPU available:  True
# Device name:  Tesla T4

# %%
#just to make sure that it is using the gpu if available
from ultralytics import YOLO
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"using device: {device}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# using device: cuda

# %%
# !pip install kaggle --quiet
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-823aa42b-90c8-429c-81b3-f48d6ab45fca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-823aa42b-90c8-429c-81b3-f48d6ab45fca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d ultralytics/medical-pills -p /content/
# !unzip -q /content/medical_pills.zip -d /content/medical-pills
# !ls /content/medical-pills
# !ls/content/medical-pills/images/train|head
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ultralytics/medical-pills
# License(s): GNU Affero General Public License 3.0
# ...
#   0% 0.00/8.20M [00:00<?, ?B/s]
# 100% 8.20M/8.20M [00:00<00:00, 1.38GB/s]
# unzip:  cannot find or open /content/medical_pills.zip, /content/medical_pills.zip.zip or /content/medical_pills.zip.ZIP.
# ls: cannot access '/content/medical-pills': No such file or directory
# /bin/bash: line 1: ls/content/medical-pills/images/train: No such file or directory

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="medical-pills.yaml", epochs=100, imgsz=640)
# Out:
# ...
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the trained model
model_path = '/content/runs/detect/train3/weights/best.pt'
model = YOLO(model_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3177238760.py in <cell line: 0>()
#       5 # Load the trained model
#       6 model_path = '/content/runs/detect/train3/weights/best.pt'
# ----> 7 model = YOLO(model_path)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      74         else:
#      75             # Continue with default YOLO initialization
# ---> 76             super().__init__(model=model, task=task, verbose=verbose)
#      77             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78                 from ultralytics import RTDETR
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     142             self._new(model, task=task, verbose=verbose)
# ...

# %%
import glob

# Get a list of image files in the validation set
val_images = glob.glob('/content/datasets/medical-pills/images/val/*.jpg')

# Choose one image for inference
if val_images:
    sample_image_path = val_images[0] # You can change this index to pick a different image
    print(f"Using sample image: {sample_image_path}")
else:
    print("No validation images found.")
    sample_image_path = None
# Out:
# No validation images found.

# %%
if sample_image_path:
    # Run inference on the sample image
    results = model(sample_image_path)

    # Show the results
    for r in results:
        im_array = r.plot()  # plot a BGR numpy array of predictions
        im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
        display(im)
else:
    print("Cannot perform inference as no sample image was found.")
# Out:
# Cannot perform inference as no sample image was found.

# %%
import os

for root, dirs, files in os.walk("runs", topdown=True):
    for f in files:
        if f.endswith(".pt"):
            print(os.path.join(root, f))
